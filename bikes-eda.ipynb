# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 KB 4.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the bikes file
bikes = pd.read_csv('test_bikes.csv', parse_dates=['datetime'])
bikes.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# Reading the trains file
trains = pd.read_csv('train_bikes.csv', parse_dates=['datetime'])
trains.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# Extracting the hours from datetime for better analysis
bikes.loc[:,('hour')] = bikes.datetime.dt.hour

cols = list(bikes.columns.values)
cols

# Rearranging the columns for better readability
bikes = bikes[['datetime',
 'hour',
 'season',
 'holiday',
 'workingday',
 'weather',
 'temp',
 'atemp',
 'humidity',
 'windspeed']]

bikes.head()
# Out:
#              datetime  hour  season  holiday  workingday  weather   temp  \
# 0 2011-01-20 00:00:00     0       1        0           1        1  10.66
# 1 2011-01-20 01:00:00     1       1        0           1        1  10.66
# 2 2011-01-20 02:00:00     2       1        0           1        1  10.66
# 3 2011-01-20 03:00:00     3       1        0           1        1  10.66
# 4 2011-01-20 04:00:00     4       1        0           1        1  10.66
#
#     atemp  humidity  windspeed
# 0  11.365        56    26.0027
# 1  13.635        56     0.0000
# 2  13.635        56     0.0000
# 3  12.880        56    11.0014
# 4  12.880        56    11.0014
